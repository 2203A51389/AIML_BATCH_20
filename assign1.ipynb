# %% [markdown]
# <a href="https://colab.research.google.com/github/2203A51389/AIML_BATCH_20/blob/main/assign1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
list=[1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
import numpy as np
lst1=[1,2,3,4,5]
arr1=np.array(lst1)
print("THE GENEATED ARRAY IS",arr1)
# Out:
# THE GENEATED ARRAY IS [1 2 3 4 5]

# %%
a=[1,2,3,4]
arr1=np.array(a)
print(type(a))
print(type(arr1))
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>

# %%
import numpy as np
arr1=np.array([11,12,13,14,15,14])
arr2=np.array([10,12,34,45,64,44])
arr3=arr1+arr2
arr4=arr1*arr2
arr5=arr1-arr2
arr6=arr1/arr2
print("the product is",arr3)
print("the multiplication is",arr4)
print("the subtraction is",arr5)
print("the division is",arr6)
# Out:
# the product is [21 24 47 59 79 58]
# the multiplication is [110 144 442 630 960 616]
# the subtraction is [  1   0 -21 -31 -49 -30]
# the division is [1.1        1.         0.38235294 0.31111111 0.234375   0.31818182]

# %%
import numpy as np
arr1=np.array([10,20,20,40,50])
arr2=np.array([1,2,3,4,5])
arr3=np.sin(arr1)
arr4=np.cos(arr2)
arr5=np.tan(arr1)
arr6=np.exp(arr2)
arr7=np.log(arr1)
print(arr3)
print(arr4)
print(arr5)
print(arr6)
print(arr7)
# Out:
# [-0.54402111  0.91294525  0.91294525  0.74511316 -0.26237485]
# [ 0.54030231 -0.41614684 -0.9899925  -0.65364362  0.28366219]
# [ 0.64836083  2.23716094  2.23716094 -1.11721493 -0.27190061]
# [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]
# [2.30258509 2.99573227 2.99573227 3.68887945 3.91202301]

# %%
import matplotlib.pyplot as plt
people = ['SHAH', 'HIDAYATH', 'NAWAAZ', 'AHMED']
age =[25, 30, 35, 40, 45]
height =[145, 151, 165, 173]
weight=[45, 55, 65, 75]
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("People's weight in kgs",fontsize=16,
fontstyle='italic')
plt.bar(x=people,height=weight, width=0.6,
color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("Weight (in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
plt.figure(figsize=(7,5))
# Main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k', alpha=0.75,bins=5)
plt.title("Histogram of patient weight",fontsize=18)
plt.xlabel("Weight in kgs",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
